# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
# list
my_list = ['this', 3, 'words', 'are','just',
{
    'waste' :'NM',
    'sub' : 'Ds',
           
} ]

my_list
# Out:
# ['this', 3, 'words', 'are', 'just', {'waste': 'NM', 'sub': 'Ds'}]

# %%
list(my_list)
# Out:
# ['this', 3, 'words', 'are', 'just', {'waste': 'NM', 'sub': 'Ds'}]

# %%
tuple(my_list)
# Out:
# ('this', 3, 'words', 'are', 'just', {'waste': 'NM', 'sub': 'Ds'})

# %%
my_list[5]
# Out:
# {'waste': 'NM', 'sub': 'Ds'}

# %%
my_list.append("hello")

# %%
my_list
# Out:
# ['this', 3, 'words', 'are', 'just', {'waste': 'NM', 'sub': 'Ds'}, 'hello']

# %%
my_list.insert(0,'why')

# %%
my_list
# Out:
# ['why',
#  'this',
#  3,
#  'words',
#  'are',
#  'just',
#  {'waste': 'NM', 'sub': 'Ds'},
#  'hello']

# %%
my_list.pop(3)
# Out:
# 'words'

# %%
my_list
# Out:
# ['why', 'this', 3, 'are', 'just', {'waste': 'NM', 'sub': 'Ds'}, 'hello']

# %%
my_list.append("fk")

# %%
my_list
# Out:
# ['why', 'this', 3, 'are', 'just', {'waste': 'NM', 'sub': 'Ds'}, 'hello', 'fk']

# %%
my_list.insert(8,"asstnt")

# %%
my_list
# Out:
# ['why',
#  'this',
#  3,
#  'are',
#  'just',
#  {'waste': 'NM', 'sub': 'Ds'},
#  'hello',
#  'fk',
#  'asstnt']

# %%
"fk" in my_list
# True because it is there
# Out:
# True

# %%
"ikigai" in my_list
# false because it doesnt belong there
# Out:
# False

# %%
'cern' not in my_list
# true bcz it is absent and we used not
# Out:
# True

# %%
3 not in my_list
# false because it is there and we are saying it is not
# Out:
# False

# %%
# concatenating and combining lists
# everything everywhere all at once

# %%
# Data Loading, Storage and file Format

"""Reading data and making it accesible
to use in a notebook is DATA LOADING


reading tabular data as  DATAFRAME object

pandas.read_............()   # function to read data

after read_ 
there can be data of
csv,xml,sql,stata,json,excel,html, etc formats of data

"""
# Out:
# 'Reading data and making it accesible\nto use in a notebook is DATA LOADING\n\n\nreading tabular data as  DATAFRAME object\n\npandas.read_............()   # function to read data\n\nafter read_ \nthere can be data of\ncsv,xml,sql,stata,json,excel,html, etc formats of data\n\n'

# %%
"""These above function convert text data into DATAFRAME

Indexing
Can treat one or more columns as the returned DataFrame, and whether to get column names from the file, arguments you provide, or not at all.

Type inference and data conversion
Includes the user-defined value conversions and custom list of missing value markers.

Date and time parsing
Includes a combining capability, including combining date and time information spread over multiple columns into a single column in the result.

Iterating
Support for iterating over chunks of very large files."""
# Out:
# 'These above function convert text data into DATAFRAME\n\nIndexing\nCan treat one or more columns as the returned DataFrame, and whether to get column names from the file, arguments you provide, or not at all.\n\nType inference and data conversion\nIncludes the user-defined value conversions and custom list of missing value markers.\n\nDate and time parsing\nIncludes a combining capability, including combining date and time information spread over multiple columns into a single column in the result.\n\nIterating\nSupport for iterating over chunks of very large files.'

# %%
# Unclean Data Issues 
# In realworld Data is messy

# %%
# CSV (comma-separated values)
"""
# csv format data example1 

a,b,c,d,message
1,2,3,4,hello
5,6,7,8,ikigai
9,1,11,12,imp

# csv format data example2
name,address,profession
ikigai,newyork,MLengineer
sid,npgj,student
pk,delhi,AIengineer

if we save this in csv fomat it will seen as table, rows, and coloumn

above data is coma-delimited csv

"""
# Out:
# '\n# csv format data example1 \n\na,b,c,d,message\n1,2,3,4,hello\n5,6,7,8,ikigai\n9,1,11,12,imp\n\n# csv format data example2\nname,address,profession\nikigai,newyork,MLengineer\nsid,npgj,student\npk,delhi,AIengineer\n\nif we save this in csv fomat it will seen as table, rows, and coloumn\n\nabove data is coma-delimited csv\n\n'

# %%
# to read above csv data
# Importing pandas library
import pandas

# read data as csv format
dataframe = pandas.read_csv("/kaggle/input/sample/sample.csv")


dataframe
# note that if we dont specify header or something the first row act as header
# a,b,c,d,message act as header 
"""
a,b,c,d,message
1,2,3,4,hello 
5,6,7,8,world
9,1,11,12,ikigai

"""
# Out:
#    a   b   c   d message
# 0  1   2   3   4   hello
# 1  5   6   7   8   world
# 2  9  10  11  12  ikigai

# %%
# lets see if header = None

df = pandas.read_csv("/kaggle/input/sample/sample.csv", header=None)

df
# See if header = None is specified 1st row donot act as header
# Out:
#    0   1   2   3        4
# 0  a   b   c   d  message
# 1  1   2   3   4    hello
# 2  5   6   7   8    world
# 3  9  10  11  12   ikigai
